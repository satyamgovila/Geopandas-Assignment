# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
from shapely.geometry import Point,Polygon

# %%
df = pd.DataFrame(
    {
        'Latitude': [28.535517],
        'Longitude':[77.391029]
    }
)

geometry = [Point(xy) for xy in zip(df.Longitude, df.Latitude)]
df = df.drop(['Longitude', 'Latitude'], axis=1)
crs = {'init': 'epsg:4326'}
gdf = geopandas.GeoDataFrame(df, crs=crs, geometry=geometry)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
ax = world.plot( color='white', edgecolor='black' ,figsize = (20,20))
gdf.plot(ax=ax, color='red')
plt.title("World map showing location of given coordinate")

plt.show()

# %%
#if given coordinates of "Delhi ""& given polygon of "India",state true/false ,if it is present inside the polygon(i.e.India)

# %%
polys = geopandas.GeoSeries(world.loc[world['name'] == 'India'].geometry).values[0]
_pnts = Point(77.580643 , 12.972442)
_pnts1 = Point(51.5074 , 0.1278)
print("Is London present inside polygon(India) : " ,_pnts1.within(polys))
print("Is Bangalore present inside polygon(India) : " ,_pnts.within(polys))
# Out:
# Is London present inside polygon(India) :  False
# Is Bangalore present inside polygon(India) :  True
